# %%
from pylab import plotfile, show, gca

# %%
import matplotlib.cbook as cbook

# %%
fname = cbook.get_sample_data('/Users/hknam/Documents/Github/DataVisualization/ch04_numerical/data/amzn.csv', asfileobj=False)

# %%
plotfile(fname, ('date', 'high', 'low', 'close'), subplots=False)

# %%
show()
